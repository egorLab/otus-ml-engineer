# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def sample(d0, d1, n=32):
    x0 = d0.sample((n,))
    x1 = d1.sample((n,))
    y0 = torch.zeros((n, 1))
    y1 = torch.ones((n, 1))
    
    return torch.cat([ x0,  x1], 0), torch.cat([y0, y1], 0)

# %%
# параметры распределений
mean_vector0, cov_matrix0 = torch.zeros(2), 2*torch.eye(2)
mean_vector1, cov_matrix1 = torch.tensor([2, 2], dtype=torch.float32), torch.eye(2)

# %%
d0 = torch.distributions.MultivariateNormal(mean_vector0, cov_matrix0)
d1 = torch.distributions.MultivariateNormal(mean_vector1, cov_matrix1)

# %%
net = nn.Sequential(nn.Linear(2, 20), nn.ReLU(), nn.Linear(20, 1))
print([p.data[0] for p in net.parameters()])
layer_opt = optim.SGD(lr=1e-3, params=list(net.parameters()))
# Out:
# [tensor([0.5554, 0.1388]), tensor(0.4903), tensor([-0.1326,  0.1642, -0.2213, -0.0718, -0.2190, -0.1059, -0.1235,  0.2155,
#         -0.0291,  0.1704,  0.1655,  0.0779, -0.2022, -0.2211, -0.1078,  0.0535,
#          0.1669, -0.0106, -0.2196,  0.1024]), tensor(0.1039)]

# %%
x_scale, y_scale = np.meshgrid(np.linspace(-5, 5, 500), np.linspace(-5, 5, 500))
pos = np.empty(x_scale.shape + (2,))
pos[:, :, 0] = x_scale; pos[:, :, 1] = y_scale

d0_pdf = stats.multivariate_normal(mean=mean_vector0.numpy(), cov=cov_matrix0.numpy()).pdf(pos)
d1_pdf = stats.multivariate_normal(mean=mean_vector1.numpy(), cov=cov_matrix1.numpy()).pdf(pos)

ratio = d1_pdf / (d1_pdf + d0_pdf)

# %%
a = plt.contour(x_scale, y_scale, d0_pdf, colors='red')
b = plt.contour(x_scale, y_scale, d1_pdf, colors='blue')
c = plt.contour(x_scale, y_scale, ratio, colors='green')

labels = ['d0_pdf', 'd1_pdf','ratio']
a.collections[0].set_label('d0_pdf')
b.collections[0].set_label('d1_pdf')
c.collections[0].set_label('ratio')

plt.legend(loc='upper left')
plt.show()

# %%
log_freq = 500
for i in range(20000):
    if i%log_freq == 0:
        with torch.no_grad():
            x, y = sample(d0, d1, 100000)
            out = torch.sigmoid(net(x))
            loss = F.binary_cross_entropy(out, y)
        print('Ошибка после %d итераций: %f' %(i/log_freq, loss))
    layer_opt.zero_grad()
    x, y = sample(d0, d1, 256)
    out = torch.sigmoid(net(x))
    loss = F.binary_cross_entropy(out, y)
    loss.backward()
    layer_opt.step()
# Out:
# Ошибка после 0 итераций: 0.832874
# Ошибка после 1 итераций: 0.521737
# Ошибка после 2 итераций: 0.468797
# Ошибка после 3 итераций: 0.432154
# Ошибка после 4 итераций: 0.408106
# Ошибка после 5 итераций: 0.386491
# Ошибка после 6 итераций: 0.368252
# Ошибка после 7 итераций: 0.355204
# Ошибка после 8 итераций: 0.343435
# Ошибка после 9 итераций: 0.335846
# Ошибка после 10 итераций: 0.328010
# Ошибка после 11 итераций: 0.319447
# Ошибка после 12 итераций: 0.316081
# Ошибка после 13 итераций: 0.310852
# Ошибка после 14 итераций: 0.306887
# Ошибка после 15 итераций: 0.303064
# Ошибка после 16 итераций: 0.297308
# Ошибка после 17 итераций: 0.296817
# Ошибка после 18 итераций: 0.293700
# Ошибка после 19 итераций: 0.292362
# Ошибка после 20 итераций: 0.288365
# Ошибка после 21 итераций: 0.290123
# Ошибка после 22 итераций: 0.287770
# Ошибка после 23 итераций: 0.286239
# Ошибка после 24 итераций: 0.285020
# Ошибка после 25 итераций: 0.283511
# Ошибка после 26 итераций: 0.281505
# Ошибка после 27 итераций: 0.282137
# Ошибка после 28 итераций: 0.280410
# Ошибка после 29 итераций: 0.280595
# Ошибка после 30 итераций: 0.279192
# Ошибка после 31 итераций: 0.280759
# Ошибка после 32 итераций: 0.279097
# Ошибка после 33 итераций: 0.278120
# Ошибка после 34 итераций: 0.278003
# Ошибка после 35 итераций: 0.276932
# Ошибка после 36 итераций: 0.278430
# Ошибка после 37 итераций: 0.275843
# Ошибка после 38 итераций: 0.276047
# Ошибка после 39 итераций: 0.277436

# %%
x_and_y_tensor = torch.tensor(np.concatenate([x_scale, y_scale]).reshape(-1, 2), dtype=torch.float)
with torch.no_grad():
    dist = torch.sigmoid(net(x_and_y_tensor)).numpy()

# %%
plt.figure(figsize=(10,10))

a = plt.contour(x_scale, y_scale, d0_pdf, colors='red')
b = plt.contour(x_scale, y_scale, d1_pdf, colors='blue')
c = plt.contour(x_scale, y_scale, dist.reshape(-1, 500), levels=[0, 0.5, 1])
d = plt.contour(x_scale, y_scale, ratio, colors='green')

labels = ['d0_pdf', 'd1_pdf','ratio', 'pred']
a.collections[0].set_label('d0_pdf')
b.collections[0].set_label('d1_pdf')
c.collections[0].set_label('pred')
d.collections[0].set_label('ratio')


plt.legend(loc='upper left')
plt.show()
